# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
sns.set(context='talk')

# %%
df = pd.read_csv("../scripts/LightDark/data/compare.csv")
df.head()
# Out:
#       sol     t          r
# 0  PFTDPW  0.01  55.629929
# 1  PFTDPW  0.01 -78.807351
# 2  PFTDPW  0.01  72.853712
# 3  PFTDPW  0.01  77.740750
# 4  PFTDPW  0.01 -78.807351

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, markers=True)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7)) 
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, markers=True)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7)) 
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, markers=True)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df.copy()
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, ci=95, lw=5)
res.set(xscale='log')
plt.xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
plt.ylabel("Mean Reward")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df[df['sol'] != "POMCP"]
res = sns.lineplot(x='t',y='r',hue='sol',data=new_df, ax=ax, ci=68, lw=5)
res.set(xscale='log')
ax.set_xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
ax.set_ylabel("Mean Reward")
plt.show()

# %%
1.971/1.184
# Out:
# 1.664695945945946
