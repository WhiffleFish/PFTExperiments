# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
sns.set(context='talk')

# %%
df = pd.read_csv("../scripts/VDPTAg/data/compare.csv")
df.head()
# Out:
#        sol         t          r
# 0   PFTDPW  0.177828  14.194513
# 1  POMCPOW  0.100000  31.702861
# 2    POMCP  0.010000 -61.804309
# 3  POMCPOW  0.017783  55.097952
# 4  POMCPOW  1.000000  28.071206

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
# new_df = df.copy()
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, ci=95, lw=5)
res.set(xscale='log')
plt.xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
plt.ylabel("Mean Reward")
plt.show()
