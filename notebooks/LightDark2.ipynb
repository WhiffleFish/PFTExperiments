# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
sns.set(context='talk')

# %%
df = pd.read_csv("../scripts/LightDark/data/compare.csv")
df.head()
# Out:
#        sol         t          r
# 0  POMCPOW  0.056234  68.211027
# 1    POMCP  0.056234 -81.902475
# 2    POMCP  0.562341  41.601050
# 3  POMCPOW  0.177828  55.629929
# 4    POMCP  0.056234  59.610452

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, markers=True)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7)) 
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, markers=True)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7)) 
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, markers=True)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax)
res.set(xscale='log')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df.copy()
res = sns.lineplot(x='t',y='r',hue='sol',data=df, ax=ax, ci=95, lw=5)
res.set(xscale='log')
plt.xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
plt.ylabel("Mean Reward")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df[df['sol'] != "POMCP"]
res = sns.lineplot(x='t',y='r',hue='sol',data=new_df, ax=ax, ci=68, lw=5)
res.set(xscale='log')
ax.set_xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
ax.set_ylabel("Mean Reward")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df[df['sol'] != "POMCP"]
res = sns.lineplot(x='t',y='r',hue='sol',data=new_df, ax=ax, ci=68, lw=5)
res.set(xscale='log')
ax.set_xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
ax.set_ylabel("Mean Reward")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df[df['sol'] != "POMCP"]
res = sns.lineplot(x='t',y='r',hue='sol',data=new_df, ax=ax, ci=68, lw=5)
res.set(xscale='log')
ax.set_xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
ax.set_ylabel("Mean Reward")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df[df['sol'] != "POMCP"]
res = sns.lineplot(x='t',y='r',hue='sol',data=new_df, ax=ax, ci=68, lw=5)
res.set(xscale='log')
ax.set_xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
ax.set_ylabel("Mean Reward")
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
new_df = df[df['sol'] != "POMCP"]
res = sns.lineplot(x='t',y='r',hue='sol',data=new_df, ax=ax, ci=68, lw=5)
res.set(xscale='log')
ax.set_xlabel("Planning Time (s)")
ax.legend(title="Solver Type")
ax.set_ylabel("Mean Reward")
plt.show()

# %%
df[(df['sol'] == 'POMCPOW') & (df['t'] == 1.0)]['r'].std()/(5000**0.5)
# Out:
# 0.8426597182451536
